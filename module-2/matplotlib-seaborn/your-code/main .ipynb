# %% [markdown]
# # Lab | Matplotlib & Seaborn
#
# #### Import all the necessary libraries here:

# %%
# Libraries
import numpy as np
import matplotlib.pyplot as plt

# %% [markdown]
# ## Challenge 1
#
# #### The data we will use in this challenge is:

# %%
x = np.arange(0,100)
y = x*2
z = x**2

# %% [markdown]
# #### Plot (x, y) and (x, z).
# There are 2 ways of doing this. Do in both ways.
#
# **Hint**: Check out the nrows, ncols and index arguments of subplots.
#
# Also, play around with the linewidth and style. Use the ones you're most happy with.

# %%
# Method 1
fig, axs = plt.subplots(ncols=1,
                        nrows=2,
                        figsize=(11,10))
axs[0].plot(x, y, label='y = 2x')
axs[1].plot(x, z, label='z = x**2')

# %% [markdown]
# #### Use plt.subplots(nrows=1, ncols=2) to create the plot.

# %%
# Method 2
fig, axs = plt.subplots(ncols=2,
                        nrows=1,
                        figsize=(11,10))
axs[0].plot(x, y, label='y = 2x')
axs[1].plot(x, z, label='z = x**2')

# %% [markdown]
# #### Use your previous code but now, resize your plot.
# **Hint**: Add the figsize argument in plt.subplots().
#
# If you want, try to add a title to the plot or even axes labels. You can also play with the fontweight and fontsize of the titles and labels.

# %%
# your code here
fig, axs = plt.subplots(ncols=2,
                        nrows=1,
                        figsize=(20,15))
axs[0].plot(x, y, label='y = 2x')
axs[0].set_title('First Subplot')
axs[0].set_xlabel('X-axis')
axs[0].set_ylabel('Y-axis')
axs[0].legend()

axs[1].plot(x, z, label='z = x**2')
axs[1].set_title('Second Subplot')
axs[1].set_xlabel('X-axis')
axs[1].set_ylabel('Y-axis')
axs[1].legend()

# %% [markdown]
# #### Now you will have to plot both $y=x^2$ and $y=e^x$ in the same plot. Create two subplots and use a normal scale in the first one and a logarithmic scale in the second one.
# **Hint**: Use `set_xscale` and `set_yscale`.

# %%
# your code here
y1 = x**2
y2 = np.exp(x)
fig, axs = plt.subplots(nrows=1, ncols=2, figsize=(15, 6))
axs[0].plot(x, y1, label='y = x^2')
axs[0].plot(x, y2, label='y = e^x')
axs[0].set_title('Normal Scale')
axs[0].set_xlabel('x')
axs[0].set_ylabel('y')

axs[1].plot(x, y1, label='y = x^2')
axs[1].plot(x, y2, label='y = e^x')
axs[1].set_yscale('log')  # Set logarithmic scale on the y-axis
axs[1].set_title('Logarithmic Scale')
axs[1].set_xlabel('x')
axs[1].set_ylabel('y (log scale)')
# Out:
# Text(0, 0.5, 'y (log scale)')

# %% [markdown]
# #### As a bonus challenge, try to add a legend to the plot.

# %%
# your code here
y1 = x**2
y2 = np.exp(x)
fig, axs = plt.subplots(nrows=1, ncols=2, figsize=(15, 6))
axs[0].plot(x, y1, label='y = x^2')
axs[0].plot(x, y2, label='y = e^x')
axs[0].set_title('Normal Scale')
axs[0].set_xlabel('x')
axs[0].set_ylabel('y')
axs[0].legend()

axs[1].plot(x, y1, label='y = x^2')
axs[1].plot(x, y2, label='y = e^x')
axs[1].set_yscale('log')  # Set logarithmic scale on the y-axis
axs[1].set_title('Logarithmic Scale')
axs[1].set_xlabel('x')
axs[1].set_ylabel('y (log scale)')
axs[1].legend()

plt.tight_layout()
plt.show()

# %% [markdown]
# ## Challenge 2
# #### Import the `Fitbit2` dataset and store it in a variable called `fitbit`. You can find the dataset in Ironhack's database:
# * db: `fitbit`
# * table: `fitbit2`

# %%
# your code here
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
fitbit2 = pd.read_csv('../data/fitbit2.csv')

# %% [markdown]
# #### From the Fitbit data, we want to visually understand:
#
# How the average number of steps change by month. Use the appropriate visualization to show the median steps by month. Is Fitbitter more active on weekend or workdays? All plots must be in the same jupyter notebook cell.
#
# **Hints**:
#
# * Use Months_encoded and Week_or Weekend columns.
# * Use matplolib.pyplot object oriented API.
# * Set your size figure to 12,4
# * Explore plt.sca
# * Explore plt.xticks
# * Save your figures in a folder called `figures` in your repo.

# %%
# MEDIAN STEPS BY MONTH_ENCODED
# your code here
fig, axes = plt.subplots(nrows=1, ncols=2, figsize=(12, 4))
plt.sca(axes[0])
sns.barplot(x='Months_encoded', y='Steps', data=fitbit2.groupby('Months_encoded')['Steps'].median().reset_index())
plt.title('Median Steps by Month')
plt.xlabel('Month')
plt.ylabel('Median Steps')
plt.xticks(range(1, 13), ['Jan', 'Feb', 'Mar', 'Apr', 'May', 'Jun', 'Jul', 'Aug', 'Sep', 'Oct', 'Nov', 'Dec'])


# MEDIAN STEPS BY WORK_OR_WEEKEND
# your code here
fig, axes = plt.subplots(nrows=1, ncols=2, figsize=(12, 4))
plt.sca(axes[1])
sns.barplot(x='Work_or_Weekend', y='Steps', data=fitbit2.groupby('Work_or_Weekend')['Steps'].median().reset_index())
plt.title('Median Steps on Workdays vs. Weekends')
plt.xlabel('Day Type')
plt.ylabel('Median Steps')
plt.xticks([0, 1], ['Workday', 'Weekend'])
plt.tight_layout()
plt.show()
# Out:
# /Users/nataliavargas/miniconda3/envs/m2_env/lib/python3.11/site-packages/seaborn/_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# /Users/nataliavargas/miniconda3/envs/m2_env/lib/python3.11/site-packages/seaborn/_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# /Users/nataliavargas/miniconda3/envs/m2_env/lib/python3.11/site-packages/seaborn/_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# ...

# %% [markdown]
# #### Write a loop to plot 3 scatter plots of the following features:
#
# * Minutes Lightly Active vs Steps
# * Minutes Very Active vs Steps
# * Minutes Sedentary vs Steps

# %%
# your code here
features_to_plot = ['Minutes Lightly Active', 'Minutes Very Active', 'Minutes Sedentary']
fig, axes = plt.subplots(1, 3, figsize=(18, 5))
for i, feature in enumerate(features_to_plot):
    plt.sca(axes[i])  # Set the current axis
    plt.scatter(fitbit2[feature], fitbit2['Steps'])
    plt.title(f'{feature} vs Steps')
    plt.xlabel(feature)
    plt.ylabel('Steps')
plt.tight_layout()
plt.show()

# %% [markdown]
# ## Challenge 3
#
# #### Import the `titanic` dataset and store it in a variable called `titanic`. You can find the dataset in Ironhack's database:
# * db: `titanic`
# * table: `titanic`

# %%
# your code here
import pandas as pd
titanic = pd.read_csv('../data/titanic.csv')

# %% [markdown]
# #### Explore the titanic dataset using Pandas dtypes.

# %%
# your code here
df_titanic = titanic
print(df_titanic.head())
print(df_titanic.dtypes)
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1       0.0       3
# 1            2       1.0       1
# 2            3       1.0       3
# 3            4       1.0       1
# 4            5       0.0       3
#
#                                                 Name  Gender   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500    U0        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250    U0        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500    U0        S
# ...

# %% [markdown]
# #### What are your numerical variables? What are your categorical variables?
# **Hint**: Use Pandas select_dtypes.

# %%
# NUMERICAL VARIABLES
# your code here
titanic.dtypes
# Out:
# PassengerId      int64
# Survived       float64
# Pclass           int64
# Name            object
# Gender          object
# Age            float64
# SibSp            int64
# Parch            int64
# Ticket          object
# Fare           float64
# Cabin           object
# Embarked        object
# dtype: object

# %%
# CATEGORICAL VARIABLES
# your code here
titanic.select_dtypes(include=['int64','float64']).info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1309 entries, 0 to 1308
# Data columns (total 7 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   PassengerId  1309 non-null   int64
#  1   Survived     891 non-null    float64
#  2   Pclass       1309 non-null   int64
#  3   Age          1309 non-null   float64
#  4   SibSp        1309 non-null   int64
#  5   Parch        1309 non-null   int64
#  6   Fare         1309 non-null   float64
# dtypes: float64(3), int64(4)
# memory usage: 71.7 KB

# %%
plt.style.available
# Out:
# ['Solarize_Light2',
#  '_classic_test_patch',
#  '_mpl-gallery',
#  '_mpl-gallery-nogrid',
#  'bmh',
#  'classic',
#  'dark_background',
#  'fast',
#  'fivethirtyeight',
#  'ggplot',
#  'grayscale',
#  'seaborn-v0_8',
#  'seaborn-v0_8-bright',
#  'seaborn-v0_8-colorblind',
#  'seaborn-v0_8-dark',
#  'seaborn-v0_8-dark-palette',
#  'seaborn-v0_8-darkgrid',
#  'seaborn-v0_8-deep',
#  'seaborn-v0_8-muted',
#  'seaborn-v0_8-notebook',
#  'seaborn-v0_8-paper',
#  'seaborn-v0_8-pastel',
#  'seaborn-v0_8-poster',
#  'seaborn-v0_8-talk',
#  'seaborn-v0_8-ticks',
#  'seaborn-v0_8-white',
#  'seaborn-v0_8-whitegrid',
#  'tableau-colorblind10']

# %% [markdown]
# #### Set the plot style to classic and the figure size to (12,6).
# **Hint**: To set the style you can use matplotlib or seaborn functions. Do some research on the matter.

# %%
# your code here
import matplotlib.pyplot as plt
fig = plt.figure(figsize=(12, 6))
plt.show()

# %% [markdown]
# #### Use the right visulalization to show the distribution of column `Age`.

# %%
# your code here
titanic['Age'].value_counts()
# Out:
# Age
# 24.000000    47
# 22.000000    43
# 21.000000    41
# 30.000000    40
# 18.000000    39
#              ..
# 45.701220     1
# 23.095064     1
# 23.926502     1
# 41.993167     1
# 38.500000     1
# Name: count, Length: 193, dtype: int64

# %% [markdown]
# #### Use subplots and plot the distribution of the `Age`  with bins equal to 10, 20 and 50.

# %%
# your code here
pd.set_option      
plt.hist(titanic['Age'])    
plt.show()
plt.hist(titanic['Age'])
plt.annotate('local max', xy =(30,350), xytext = (50, 300),  arrowprops=dict(facecolor ='yellow', shrink= 1.7),)    
plt.show()

# %% [markdown]
# #### How does the bin size affect your plot?

# %%
"""
your comments here
"""

# %% [markdown]
# #### Use seaborn to show the distribution of column `Age`.

# %%
# your code here

# %% [markdown]
# #### Use the right plot to visualize column `Gender`. There are 2 ways of doing it. Do it both ways.
# **Hint**: Use matplotlib and seaborn.

# %%
# Method 1 - matplotlib
# your code here
fig, ax= plt.subplots(nrows=1, ncols=1)
plt.pie(titanic['Gender'].value_counts())
plt.legend(labels=['Male','Female'],frameon=True)
plt.title('Gender distribution');
plt.show()

# %%
# Method 2 - seaborn
# your code here
sns.countplot(x=titanic["Gender"])
plt.show()
# Out:
# /Users/nataliavargas/miniconda3/envs/m2_env/lib/python3.11/site-packages/seaborn/_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# /Users/nataliavargas/miniconda3/envs/m2_env/lib/python3.11/site-packages/seaborn/_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# /Users/nataliavargas/miniconda3/envs/m2_env/lib/python3.11/site-packages/seaborn/_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):

# %% [markdown]
# #### Use the right plot to visualize the column `Pclass`.

# %%
# your code here
sns.countplot(x=titanic["Pclass"])
plt.show()
# Out:
# /Users/nataliavargas/miniconda3/envs/m2_env/lib/python3.11/site-packages/seaborn/_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# /Users/nataliavargas/miniconda3/envs/m2_env/lib/python3.11/site-packages/seaborn/_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# /Users/nataliavargas/miniconda3/envs/m2_env/lib/python3.11/site-packages/seaborn/_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):

# %%
ax= sns.countplot
ax.bar_label(ax.containers[0])
plt.show()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[42], line 2
#       1 ax= sns.countplot
# ----> 2 ax.bar_label(ax.containers[0])
#       3 plt.show()
#
# AttributeError: 'function' object has no attribute 'bar_label'

# %% [markdown]
# #### We would like to have in one single plot the summary statistics of the feature `Age`. What kind of plot would you use? Plot it.

# %%
# your code here
titanic["Age"]
# Out:
# 0       22.000000
# 1       38.000000
# 2       26.000000
# 3       35.000000
# 4       35.000000
#           ...
# 1304    29.513190
# 1305    39.000000
# 1306    38.500000
# 1307    29.513190
# 1308    25.315435
# Name: Age, Length: 1309, dtype: float64

# %%
ax = sns. boxplot(x=titanic['Age'], showmeans=True)
ax.axvline(x=titanic['Age'].median(), color='g', linestyle='-',label='Median')
ax.axvline(x=titanic['Age'].mean(), color='r', linestyle='-',label='Mean')
ax. legend (loc= 'best')
plt. show()

# %%
"""
your comments here
"""

# %% [markdown]
# #### What does the last plot tell you about the feature `Age`?

# %%
"""
your comments here
"""

# %% [markdown]
# #### Now in addition to the summary statistics, we want to have in the same plot the distribution of `Age`. What kind of plot would you use? Plot it.

# %%
# your code here

# %% [markdown]
# #### What additional information does the last plot provide about feature `Age`?

# %%
"""
your comments here
"""

# %% [markdown]
# #### We suspect that there is a linear relationship between `Fare` and `Age`. Use the right plot to show the relationship between these 2 features. There are 2 ways, please do it both ways.
# **Hint**: Use matplotlib and seaborn.

# %%
# Method 1 - matplotlib
# your code here
plt.scatter(data=titanic,
            x= 'Age',
            y= 'Fare')
plt.show()

# %%
# Method 2 - seaborn
# your code here
sns.scatterplot(data=titanic, x="Age", y="Fare")
plt.show()
# Out:
# /Users/nataliavargas/miniconda3/envs/m2_env/lib/python3.11/site-packages/seaborn/_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# /Users/nataliavargas/miniconda3/envs/m2_env/lib/python3.11/site-packages/seaborn/_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):

# %% [markdown]
# #### Plot the correlation matrix using seaborn.

# %%
import seaborn as sns
# your code here
corr = titanic.corr(numeric_only = True)
sns.heatmap(corr)
plt.show()

# %% [markdown]
# #### What are the most correlated features?

# %%
"""

"""

# %% [markdown]
# #### Use the most appropriate plot to display the summary statistics of `Age` depending on `Pclass`.

# %%
# your code here
titanic.columns
# Out:
# Index(['PassengerId', 'Survived', 'Pclass', 'Name', 'Gender', 'Age', 'SibSp',
#        'Parch', 'Ticket', 'Fare', 'Cabin', 'Embarked'],
#       dtype='object')

# %%
sns.boxplot(data= titanic, x='Pclass', y='Age')
plt.show()
# Out:
# /Users/nataliavargas/miniconda3/envs/m2_env/lib/python3.11/site-packages/seaborn/_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# /Users/nataliavargas/miniconda3/envs/m2_env/lib/python3.11/site-packages/seaborn/_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# /Users/nataliavargas/miniconda3/envs/m2_env/lib/python3.11/site-packages/seaborn/_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):

# %% [markdown]
# #### Use seaborn to plot the distribution of `Age` based on the `Gender`.
# **Hint**: Use Facetgrid.

# %%
# your code here
g = sns.FacetGrid(titanic, col= 'Gender')
g.map(plt.hist, 'Age')
plt.show()
# Out:
# /Users/nataliavargas/miniconda3/envs/m2_env/lib/python3.11/site-packages/seaborn/_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
